# %%
import surprise
## 고유값(특이값)분해 방법
from surprise import SVD
## SGD(Stochastic 통계적인 Gradient 경사 하강법)
from surprise import Dataset, Reader
from surprise import accuracy
from surprise.model_selection import train_test_split
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
import pandas as pd
import numpy as np

# %%
def get_dataframe():
    rating = pd.read_csv('ratings_trip.csv', index_col=0)
    area = pd.read_csv('place_trip.csv', index_col=0)
    user = pd.read_csv('user_trip.csv', index_col=0)
    return user, area, rating

# %%
def cal_RMSE(rating):
    algo = SVD()
    
    data = Dataset.load_from_df(rating[['userID', 'area', 'rating']], reader)
    trainset, testset = train_test_split(data, test_size=0.25, random_state=0)
    algo.fit(trainset)
    predictions = algo.test(testset)
    accuracy.rmse(predictions)
    return (algo, trainset, testset)

# %%
def get_recommendations(userID, algo, num_of_ppl=50, cosine_sim=cosine_sim):
    # model 호출    
    # 간단 전처리
    user_df = pd.get_dummies(user)
    col_data = user_df.iloc[:,1:].columns
    user_matrix = user_df.iloc[:,1:].to_numpy()
    cosine_sim = cosine_similarity(user_matrix,user_matrix)
    
    # 선택한 유저의 id로부터 해당 유저의 인덱스를 받아온다.
    userID_to_index = dict(zip(user_df['userID'], user.index))
    idx = userID_to_index[userID]

    # 해당 유저와 모든 유저와의 유사도를 가져온다.
    sim_scores = list(enumerate(cosine_sim[idx]))

    # 유사도에 따라 유저들을 정렬한다.
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # 가장 유사한 50개의 유저를 받아온다.
    sim_scores = sim_scores[1:num_of_ppl+1]

    # 가장 유사한 10개의 유저의 인덱스를 얻는다.
    user_indices = [idx[0] for idx in sim_scores]

    # 가장 유사한 10개의 유저의 id을 r_list에 저장.
    rlist = list(user_df['userID'].iloc[user_indices])
    print("가장 유사한",num_of_ppl,"명의 userID:\n", rlist)
    ##비슷한 유저 num_of_ppl명
    similar_users = user_df[user_df['userID'].isin(rlist)]
    
    similarity = cosine_similarity(similar_users, similar_users)
    print("\n\n")
    print("비슷한 유저",num_of_ppl,"명을 비교한 cosine similarity:\n", similarity)
    
    ## 비슷한 사람들 20명이 4이상 점수를 준 여행지역
    df_sim = rating[(rating['userID'].isin(rlist)) & (rating['rating']>=4)]
    print("\n\n비슷한 사람들",num_of_ppl,"명이 4이상 점수를 준 여행지역:\n", df_sim)

    ## 유저가 여행지역에 줄 점수 예측
    result= [(algo.predict(userID, str(one), verbose=True)) for one in df_sim['area']]
    print("\n\n유저가 여행지역에 줄 점수 예측:")
    for i in result:
        print(i)
    
    result_est = [pred.est for pred in result]
    result_est = list(set(result_est))
    # print(result_est)
    
    ## 여행지역중 최대 평점 예측되는 지역 top 5
    top5 = sorted(range(len(result_est)), key=lambda i: result_est[i])[-5:]
    top5.reverse()
    
    ## top5여행지에 대한 유저 평가 예측
    recommendation = []
    print("\n\n top5여행지에 대한 유저 평가 예측:\n")
    for i in top5:
        print(result[i])
        recommendation.append(result[i][1])
    
    return recommendation

# %%
reader = Reader(rating_scale=(1,5.0)) # 1단위, 최대값 5

# %%
user, area, rating = get_dataframe()

# %%
algo, trainset, testset = cal_RMSE(rating)
# Out:
# RMSE: 0.4740

# %%
get_recommendations(1000203, algo, 50)
# Out:
# 가장 유사한 50 명의 userID:
#  [1002202, 1005502, 1000701, 1024002, 1021102, 1021802, 1023703, 1095702, 1034201, 1158002, 1039501, 1046001, 1069002, 1086902, 1038102, 1026402, 1028502, 1090702, 1243702, 1021101, 1013001, 1060204, 1004802, 1326002, 1104302, 1034501, 1004601, 1061001, 1114802, 1085202, 1005501, 1047501, 1125902, 1076003, 1166804, 1024001, 1100502, 1082902, 1202802, 1140302, 1112302, 1157302, 1193702, 1173202, 1270602, 1118702, 1127402, 1000702, 1008602, 1031701]
#
#
#
# 비슷한 유저 50 명을 비교한 cosine similarity:
#  [[1.         1.         0.99999929 ... 0.99999986 0.99999963 0.99999679]
#  [1.         1.         0.99999929 ... 0.99999986 0.99999963 0.99999679]
#  [0.99999929 0.99999929 1.         ... 0.99999851 0.9999979  0.99999306]
#  ...
#  [0.99999986 0.99999986 0.99999851 ... 1.         0.99999995 0.999998  ]
#  [0.99999963 0.99999963 0.9999979  ... 0.99999995 1.         0.9999986 ]
#  [0.99999679 0.99999679 0.99999306 ... 0.999998   0.9999986  1.        ]]
#
#
# 비슷한 사람들 50 명이 4이상 점수를 준 여행지역:
#         userID  rating          area
# 12    1000701     4.0       강원도 동해시
# 13    1000701     4.0      경상북도 영덕군
# 44    1002202     4.0      경기도 남양주시
# 99    1004601     4.0       경기도 이천시
# 100   1004601     4.0       경기도 이천시
# 101   1004601     4.0       경기도 양평군
# 102   1004601     4.0       경기도 양평군
# 257   1008602     4.0       경기도 수원시
# 258   1008602     4.0       강원도 강릉시
# 260   1008602     4.0      충청남도 태안군
# 261   1008602     4.0      전라북도 전주시
# 656   1024002     4.0       강원도 속초시
# 758   1028502     4.0      충청남도 태안군
# 1247  1046001     4.0     인천광역시 강화군
# 1249  1046001     5.0       강원도 동해시
# 1250  1046001     5.0      충청북도 충주시
# 1251  1046001     5.0      전라남도 목포시
# 2336  1082902     4.0      경상북도 청도군
# 2339  1082902     4.0      경상남도 거제시
# 2340  1082902     4.0      경상남도 거제시
# 2532  1086902     4.0      충청북도 보은군
# 2535  1086902     4.0      경상북도 청송군
# 3001  1100502     4.0       경기도 가평군
# 3478  1114802     5.0       경기도 화성시
# 3479  1114802     5.0      전라남도 구례군
# 3480  1114802     5.0  제주특별자치도 서귀포시
# 3634  1118702     4.0      대전광역시 동구
# 3636  1118702     4.0      충청남도 태안군
# 3637  1118702     4.0      경상북도 영덕군
# 3877  1125902     5.0      대구광역시 동구
# 3878  1125902     5.0      대구광역시 동구
# 5298  1166804     4.0      충청남도 당진시
# 5537  1173202     4.0       경기도 양평군
# 5538  1173202     4.0      경상남도 하동군
# 6539  1202802     4.0      충청북도 괴산군
# 8205  1243702     4.0      경상북도 경주시
# 8206  1243702     4.0      경상남도 남해군
# 9140  1270602     4.0      경상북도 포항시
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.00   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.16   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 강원도 강릉시    r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 강원도 속초시    r_ui = None   est = 4.16   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.24   {'was_impossible': False}
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.00   {'was_impossible': False}
# user: 1000203    item: 충청북도 충주시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 전라남도 목포시   r_ui = None   est = 4.11   {'was_impossible': False}
# user: 1000203    item: 경상북도 청도군   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 1000203    item: 충청북도 보은군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 경상북도 청송군   r_ui = None   est = 3.89   {'was_impossible': False}
# user: 1000203    item: 경기도 가평군    r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 전라남도 구례군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 제주특별자치도 서귀포시 r_ui = None   est = 4.26   {'was_impossible': False}
# user: 1000203    item: 대전광역시 동구   r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 충청남도 당진시   r_ui = None   est = 4.22   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경상남도 하동군   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 1000203    item: 충청북도 괴산군   r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경상북도 경주시   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경상남도 남해군   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 1000203    item: 경상북도 포항시   r_ui = None   est = 3.98   {'was_impossible': False}
#
#
# 유저가 여행지역에 줄 점수 예측:
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.00   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.16   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 강원도 강릉시    r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 강원도 속초시    r_ui = None   est = 4.16   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.24   {'was_impossible': False}
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.00   {'was_impossible': False}
# user: 1000203    item: 충청북도 충주시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 전라남도 목포시   r_ui = None   est = 4.11   {'was_impossible': False}
# user: 1000203    item: 경상북도 청도군   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 1000203    item: 충청북도 보은군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 경상북도 청송군   r_ui = None   est = 3.89   {'was_impossible': False}
# user: 1000203    item: 경기도 가평군    r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 전라남도 구례군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 제주특별자치도 서귀포시 r_ui = None   est = 4.26   {'was_impossible': False}
# user: 1000203    item: 대전광역시 동구   r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 충청남도 당진시   r_ui = None   est = 4.22   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경상남도 하동군   r_ui = None   est = 4.42   {'was_impossible': False}
# user: 1000203    item: 충청북도 괴산군   r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경상북도 경주시   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경상남도 남해군   r_ui = None   est = 4.14   {'was_impossible': False}
# user: 1000203    item: 경상북도 포항시   r_ui = None   est = 3.98   {'was_impossible': False}
# [3.9649553375606694, 3.9525189201194277, 3.9986206059559497, 4.208681232986199, 4.1610373314078615, 3.9129918376465143, 4.0523512918021884, 4.050611057443118, 4.12617186841242, 4.159931605891593, 4.235312244850144, 3.981164093466969, 4.110088629712861, 4.006112604410497, 4.216535564324056, 4.415763889450906, 4.04889335517003, 4.141218949342557, 3.952443487704818, 3.893197580650022, 3.9890416007099256, 3.9137128197874906, 3.9633936909682026, 4.04185374472707, 4.142134149381325, 4.061198549807798, 4.061547200637654, 4.057838296448607, 4.26116343135543]
#
#
#  top5여행지에 대한 유저 평가 예측:
#
# user: 1000203    item: 충청북도 충주시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.21   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.00   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.96   {'was_impossible': False}
# ['충청북도 충주시', '경상북도 영덕군', '전라북도 전주시', '강원도 동해시', '경기도 이천시']

# %%
# pearson_sim = user_df.T.corr()
# np.array(pearson_sim)

# %%
# Out:
# 가장 유사한 100 명의 userID:
#  [1002202, 1005502, 1000701, 1024002, 1021102, 1021802, 1023703, 1095702, 1034201, 1158002, 1039501, 1046001, 1069002, 1086902, 1038102, 1026402, 1028502, 1090702, 1243702, 1021101, 1013001, 1060204, 1004802, 1326002, 1104302, 1034501, 1004601, 1061001, 1114802, 1085202, 1005501, 1047501, 1125902, 1076003, 1166804, 1024001, 1100502, 1082902, 1202802, 1140302, 1112302, 1157302, 1193702, 1173202, 1270602, 1118702, 1127402, 1000702, 1008602, 1031701, 1072802, 1025902, 1026702, 1106502, 1041001, 1060203, 1507902, 1181802, 1043001, 1050401, 1180902, 1253602, 1193701, 1001702, 1215103, 1001701, 1077402, 1061002, 1164502, 1083801, 1501504, 1063103, 1095701, 1078202, 1137902, 1183802, 1017002, 1268302, 1120401, 1140301, 1158101, 1237701, 1090701, 1100501, 1171702, 1024102, 1028602, 1047502, 1266202, 1127101, 1150401, 1001802, 1016401, 1101502, 1050101, 1058801, 1099501, 1124403, 1002201, 1149101]
#
#
#
# 비슷한 유저 100 명을 비교한 cosine similarity:
#  [[1.         1.         0.99999929 ... 0.99999679 0.99999892 0.99999967]
#  [1.         1.         0.99999929 ... 0.99999679 0.99999892 0.99999967]
#  [0.99999929 0.99999929 1.         ... 0.99999305 0.99999646 0.99999798]
#  ...
#  [0.99999679 0.99999679 0.99999305 ... 1.         0.99999943 0.99999853]
#  [0.99999892 0.99999892 0.99999646 ... 0.99999943 1.         0.99999979]
#  [0.99999967 0.99999967 0.99999798 ... 0.99999853 0.99999979 1.        ]]
#
#
# 비슷한 사람들 100 명이 4이상 점수를 준 여행지역:
#          userID  rating          area
# 12     1000701     4.0       강원도 동해시
# 13     1000701     4.0      경상북도 영덕군
# 29     1001702     4.0      경기도 남양주시
# 30     1001702     4.0       강원도 속초시
# 43     1002201     4.0     인천광역시 강화군
# ...        ...     ...           ...
# 9140   1270602     4.0      경상북도 포항시
# 9931   1501504     4.0     대구광역시 달성군
# 9932   1501504     4.0     대구광역시 달성군
# 9933   1501504     4.0       경기도 수원시
# 10104  1507902     4.0  제주특별자치도 서귀포시
#
# [79 rows x 3 columns]
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.03   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 강원도 속초시    r_ui = None   est = 4.30   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 강원도 평창군    r_ui = None   est = 4.12   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.81   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.81   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 강원도 강릉시    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 강원도 홍천군    r_ui = None   est = 4.08   {'was_impossible': False}
# user: 1000203    item: 강원도 속초시    r_ui = None   est = 4.30   {'was_impossible': False}
# user: 1000203    item: 강원도 정선군    r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 강원도 정선군    r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 하남시    r_ui = None   est = 3.98   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 강원도 원주시    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 강원도 원주시    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 충청북도 청주시   r_ui = None   est = 3.75   {'was_impossible': False}
# user: 1000203    item: 충청남도 홍성군   r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 전라남도 목포시   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 전라남도 신안군   r_ui = None   est = 3.71   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.03   {'was_impossible': False}
# user: 1000203    item: 충청북도 충주시   r_ui = None   est = 3.93   {'was_impossible': False}
# user: 1000203    item: 전라남도 목포시   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 경상북도 청도군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 경상북도 포항시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 충청북도 보은군   r_ui = None   est = 4.02   {'was_impossible': False}
# user: 1000203    item: 경상북도 청송군   r_ui = None   est = 3.86   {'was_impossible': False}
# user: 1000203    item: 경기도 오산시    r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경기도 가평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 전라남도 구례군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 제주특별자치도 서귀포시 r_ui = None   est = 4.25   {'was_impossible': False}
# user: 1000203    item: 대전광역시 동구   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 전라남도 구례군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 부산광역시 서구   r_ui = None   est = 3.93   {'was_impossible': False}
# user: 1000203    item: 부산광역시 서구   r_ui = None   est = 3.93   {'was_impossible': False}
# user: 1000203    item: 부산광역시 해운대구 r_ui = None   est = 4.12   {'was_impossible': False}
# user: 1000203    item: 전라남도 영암군   r_ui = None   est = 3.97   {'was_impossible': False}
# user: 1000203    item: 전라남도 영암군   r_ui = None   est = 3.97   {'was_impossible': False}
# user: 1000203    item: 전라북도 부안군   r_ui = None   est = 4.18   {'was_impossible': False}
# user: 1000203    item: 전라남도 영광군   r_ui = None   est = 4.26   {'was_impossible': False}
# user: 1000203    item: 충청남도 당진시   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 경상남도 하동군   r_ui = None   est = 4.30   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 광주시    r_ui = None   est = 4.07   {'was_impossible': False}
# user: 1000203    item: 강원도 양양군    r_ui = None   est = 4.17   {'was_impossible': False}
# user: 1000203    item: 충청북도 단양군   r_ui = None   est = 3.92   {'was_impossible': False}
# user: 1000203    item: 충청북도 괴산군   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 인천광역시 중구   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 광주광역시 서구   r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 광주광역시 서구   r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 경상북도 경주시   r_ui = None   est = 3.85   {'was_impossible': False}
# user: 1000203    item: 경상남도 남해군   r_ui = None   est = 4.16   {'was_impossible': False}
# user: 1000203    item: 경상북도 포항시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 대구광역시 달성군  r_ui = None   est = 4.17   {'was_impossible': False}
# user: 1000203    item: 대구광역시 달성군  r_ui = None   est = 4.17   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 제주특별자치도 서귀포시 r_ui = None   est = 4.25   {'was_impossible': False}
#
#
# 유저가 여행지역에 줄 점수 예측:
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.03   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 강원도 속초시    r_ui = None   est = 4.30   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 강원도 평창군    r_ui = None   est = 4.12   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.81   {'was_impossible': False}
# user: 1000203    item: 경기도 이천시    r_ui = None   est = 3.81   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 강원도 강릉시    r_ui = None   est = 4.18   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 강원도 홍천군    r_ui = None   est = 4.08   {'was_impossible': False}
# user: 1000203    item: 강원도 속초시    r_ui = None   est = 4.30   {'was_impossible': False}
# user: 1000203    item: 강원도 정선군    r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 강원도 정선군    r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 하남시    r_ui = None   est = 3.98   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 강원도 원주시    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 강원도 원주시    r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 충청북도 청주시   r_ui = None   est = 3.75   {'was_impossible': False}
# user: 1000203    item: 충청남도 홍성군   r_ui = None   est = 3.91   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 전라남도 목포시   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 전라남도 신안군   r_ui = None   est = 3.71   {'was_impossible': False}
# user: 1000203    item: 인천광역시 강화군  r_ui = None   est = 4.13   {'was_impossible': False}
# user: 1000203    item: 강원도 동해시    r_ui = None   est = 4.03   {'was_impossible': False}
# user: 1000203    item: 충청북도 충주시   r_ui = None   est = 3.93   {'was_impossible': False}
# user: 1000203    item: 전라남도 목포시   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 경상북도 청도군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 경상남도 거제시   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 경상북도 포항시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 충청북도 보은군   r_ui = None   est = 4.02   {'was_impossible': False}
# user: 1000203    item: 경상북도 청송군   r_ui = None   est = 3.86   {'was_impossible': False}
# user: 1000203    item: 경기도 오산시    r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 경기도 가평군    r_ui = None   est = 3.95   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 3.96   {'was_impossible': False}
# user: 1000203    item: 전라남도 구례군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 제주특별자치도 서귀포시 r_ui = None   est = 4.25   {'was_impossible': False}
# user: 1000203    item: 대전광역시 동구   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 충청남도 태안군   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 경상북도 영덕군   r_ui = None   est = 4.05   {'was_impossible': False}
# user: 1000203    item: 전라남도 구례군   r_ui = None   est = 4.06   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 대구광역시 동구   r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 부산광역시 서구   r_ui = None   est = 3.93   {'was_impossible': False}
# user: 1000203    item: 부산광역시 서구   r_ui = None   est = 3.93   {'was_impossible': False}
# user: 1000203    item: 부산광역시 해운대구 r_ui = None   est = 4.12   {'was_impossible': False}
# user: 1000203    item: 전라남도 영암군   r_ui = None   est = 3.97   {'was_impossible': False}
# user: 1000203    item: 전라남도 영암군   r_ui = None   est = 3.97   {'was_impossible': False}
# user: 1000203    item: 전라북도 부안군   r_ui = None   est = 4.18   {'was_impossible': False}
# user: 1000203    item: 전라남도 영광군   r_ui = None   est = 4.26   {'was_impossible': False}
# user: 1000203    item: 충청남도 당진시   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 경기도 양평군    r_ui = None   est = 3.94   {'was_impossible': False}
# user: 1000203    item: 경상남도 하동군   r_ui = None   est = 4.30   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 광주시    r_ui = None   est = 4.07   {'was_impossible': False}
# user: 1000203    item: 강원도 양양군    r_ui = None   est = 4.17   {'was_impossible': False}
# user: 1000203    item: 충청북도 단양군   r_ui = None   est = 3.92   {'was_impossible': False}
# user: 1000203    item: 충청북도 괴산군   r_ui = None   est = 3.99   {'was_impossible': False}
# user: 1000203    item: 인천광역시 중구   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 광주광역시 서구   r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 광주광역시 서구   r_ui = None   est = 4.09   {'was_impossible': False}
# user: 1000203    item: 경상북도 경주시   r_ui = None   est = 3.85   {'was_impossible': False}
# user: 1000203    item: 경상남도 남해군   r_ui = None   est = 4.16   {'was_impossible': False}
# user: 1000203    item: 경상북도 포항시   r_ui = None   est = 4.04   {'was_impossible': False}
# user: 1000203    item: 대구광역시 달성군  r_ui = None   est = 4.17   {'was_impossible': False}
# user: 1000203    item: 대구광역시 달성군  r_ui = None   est = 4.17   {'was_impossible': False}
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 제주특별자치도 서귀포시 r_ui = None   est = 4.25   {'was_impossible': False}
# [3.8067662319682394, 4.12826211838039, 4.100473738606254, 4.030695440598089, 4.045933670704381, 4.295401914233971, 4.117568889777195, 3.9374330664905353, 4.14641519093744, 4.1827371115538945, 4.096229385494252, 4.092885735713126, 3.905018626485097, 3.714729361715751, 3.8626366796678226, 3.8503417497187833, 4.168770782379103, 4.00680487689092, 4.0800348572598395, 4.005576950514911, 4.057475389564695, 4.2975883978593785, 4.067707668581447, 4.1617876582040285, 4.16862759630584, 3.9305414609301157, 3.9247871675693866, 3.9880102150581433, 4.258115370374477, 4.098766673653455, 3.9762660018372094, 3.910360808583884, 3.9337012708093537, 3.9642042219496245, 3.951015822066144, 4.0908164931579245, 4.048829732597345, 4.059578608798637, 4.037077432278985, 4.019778019713143, 4.247069733321756, 4.046721286091386, 4.147873324262366, 4.121200461395378, 4.182751512432307, 3.9673379804505506, 3.7482061841015173, 3.9854587813762463, 3.9901973639145267]
#
#
#  top5여행지에 대한 유저 평가 예측:
#
# user: 1000203    item: 경기도 수원시    r_ui = None   est = 4.15   {'was_impossible': False}
# user: 1000203    item: 경기도 남양주시   r_ui = None   est = 4.10   {'was_impossible': False}
# user: 1000203    item: 전라북도 전주시   r_ui = None   est = 4.01   {'was_impossible': False}
# user: 1000203    item: 경상북도 청송군   r_ui = None   est = 3.86   {'was_impossible': False}
# user: 1000203    item: 경기도 화성시    r_ui = None   est = 3.96   {'was_impossible': False}
# ['경기도 수원시', '경기도 남양주시', '전라북도 전주시', '경상북도 청송군', '경기도 화성시']

# %%
 ## 유사한 유저 50명 정보 출력
# user[user_df['userID'].isin(rlist)]

# %%
# import seaborn as sns
# from matplotlib import pyplot as plt

# sns.heatmap(cosine_sim, xticklabels=similar_users['userID'], yticklabels=similar_users['userID'], cmap='viridis')
# plt.show()
