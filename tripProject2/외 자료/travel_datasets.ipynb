# %%
import pandas as pd
import scipy.io as spio
import numpy as np
import csv
import Sav
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8764\926589655.py in <module>
#       3 import numpy as np
#       4 import csv
# ----> 5 import Sav
#
# ModuleNotFoundError: No module named 'Sav'

# %%
df = pd.read_spss('kor_data_19990012휴가.sav')
df
# Out:
#           id        area             area1   sex   age   q1  \
# 0        2.0  °æ±âµµ½ÃºÎ  ±¤ÁÖ ¿Ü ´Ù¸¥Áö¿ª  ¿©ÀÚ  28.0  3.0
# 1        3.0  °æ±âµµ±ººÎ  ±¤ÁÖ ¿Ü ´Ù¸¥Áö¿ª  ¿©ÀÚ  51.0  4.0
# 2        5.0  °æ±âµµ±ººÎ  ±¤ÁÖ ¿Ü ´Ù¸¥Áö¿ª  ¿©ÀÚ  56.0  4.0
# 3        7.0        ¼­¿ï  ±¤ÁÖ ¿Ü ´Ù¸¥Áö¿ª  ¿©ÀÚ  65.0  4.0
# 4        8.0        ¼­¿ï  ±¤ÁÖ ¿Ü ´Ù¸¥Áö¿ª  ¿©ÀÚ  60.0  2.0
# ...      ...         ...               ...   ...   ...  ...
# 1367  1007.0   ±¤ÁÖ ºÏ±¸              ±¤ÁÖ  ³²ÀÚ  37.0  3.0
# 1368   704.0   ±¤ÁÖ ³²±¸              ±¤ÁÖ  ¿©ÀÚ  22.0  4.0
# 1369   518.0   ±¤ÁÖ ºÏ±¸              ±¤ÁÖ  ¿©ÀÚ  29.0  4.0
# 1370   562.0   ±¤ÁÖ ¼­±¸              ±¤ÁÖ  ¿©ÀÚ  22.0  6.0
# 1371  1152.0        ´ë±¸  ±¤ÁÖ ¿Ü ´Ù¸¥Áö¿ª  ³²ÀÚ  20.0  4.0
#
#                                                q2                       q3  \
# 0                  ºÎºÎ¿Í ¹ÌÈ¥ÀÎ ÀÚ³à°¡ °°ÀÌ »ê´Ù  Æ¯º°È÷ ÈÞ°¡ ±â°£ÀÌ ¾ø´Ù
# 1                  ºÎºÎ¿Í ¹ÌÈ¥ÀÎ ÀÚ³à°¡ °°ÀÌ »ê´Ù  Æ¯º°È÷ ÈÞ°¡ ±â°£ÀÌ ¾ø´Ù
# ...

# %%
from savReaderWriter import SavReader

# %%
raw_data = SavReader('C:/Users/hi/Downloads/20.500.12236_12316/kor_data_19990012.sav', returnHeader = True, ioUtf8=True)
raw_data_list = list(raw_data)
data = pd.DataFrame(raw_data_list)
data_vac = data.rename(columns=data.loc[0]).iloc[1:]
data_vac
# Out:
#        b'id' b'area' b'area1' b'sex' b'age' b'q1' b'q2' b'q3' b'q3_1'  \
# 1        2.0    11.0      2.0    2.0   28.0   3.0   2.0   3.0     0.0
# 2        3.0    12.0      2.0    2.0   51.0   4.0   2.0   3.0     0.0
# 3        5.0    12.0      2.0    2.0   56.0   4.0   1.0   3.0     0.0
# 4        7.0     1.0      2.0    2.0   65.0   4.0   4.0   3.0     0.0
# 5        8.0     1.0      2.0    2.0   60.0   2.0   1.0   3.0     0.0
# ...      ...     ...      ...    ...    ...   ...   ...   ...     ...
# 1368  1007.0    34.0      1.0    1.0   37.0   3.0   2.0   1.0     1.0
# 1369   704.0    33.0      1.0    2.0   22.0   4.0   2.0   1.0     1.0
# 1370   518.0    34.0      1.0    2.0   29.0   4.0   2.0   3.0     0.0
# 1371   562.0    32.0      1.0    2.0   22.0   6.0   2.0   1.0     1.0
# 1372  1152.0     4.0      2.0    1.0   20.0   4.0   2.0   2.0     0.0
#
#      b'q3_2a1'  ... b'q16_3' b'q16_4' b'q16_5' b'q17' b'q18' b'q18_1' b'occu'  \
# ...

# %%
raw_data = SavReader('kor_data_19990010.sav', returnHeader = True, ioUtf8=True)
raw_data_list = list(raw_data)
data = pd.DataFrame(raw_data_list)
data_gen = data.rename(columns=data.loc[0]).iloc[1:]
data_gen
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3372\148504300.py in <module>
# ----> 1 raw_data = SavReader('kor_data_19990010.sav', returnHeader = True, ioUtf8=True)
#       2 raw_data_list = list(raw_data)
#       3 data = pd.DataFrame(raw_data_list)
#       4 data_gen = data.rename(columns=data.loc[0]).iloc[1:]
#       5 data_gen
#
# ~\Anaconda3\lib\site-packages\savReaderWriter\savReader.py in __init__(self, savFileName, returnHeader, recodeSysmisTo, verbose, selectVars, idVar, rawMode, ioUtf8, ioLocale)
#      79         """ Constructor. Initializes all vars that can be recycled """
#      80         super(SavReader, self).__init__(savFileName, b"rb", None,
# ---> 81                                         ioUtf8, ioLocale)
#      82         self.savFileName = savFileName
#      83         self.returnHeader = returnHeader
#
# ...

# %%
data1 = pd.get_dummies(data)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 1 to 1372
# Columns: 2531 entries, id_1.0 to educ_99.0
# dtypes: uint8(2531)
# memory usage: 3.3 MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 1 to 1372
# Data columns (total 73 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1372 non-null   object
#  1   area      1372 non-null   object
#  2   area1     1372 non-null   object
#  3   sex       1372 non-null   object
#  4   age       1372 non-null   object
#  5   q1        1372 non-null   object
#  6   q2        1372 non-null   object
#  7   q3        1372 non-null   object
#  8   q3_1      1372 non-null   object
#  9   q3_2a1    1372 non-null   object
#  10  q3_2a2    1372 non-null   object
#  11  q3_3a1    1372 non-null   object
#  12  q3_3a2    1372 non-null   object
#  13  q3_2b1    1372 non-null   object
#  14  q3_2b2    1372 non-null   object
#  15  q3_3b1    1372 non-null   object
#  16  q3_3b2    1372 non-null   object
#  17  q3_2c1    1372 non-null   object
#  18  q3_2c2    1372 non-null   object
#  19  q3_3c1    1372 non-null   object
# ...

# %%
data_gen.to_csv('1999 전국민 일반 csv.csv')
